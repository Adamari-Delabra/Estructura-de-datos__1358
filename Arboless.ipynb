# %% [markdown]
# <a href="https://colab.research.google.com/github/Adamari-Delabra/Estructura-de-datos__1358/blob/main/Arboless.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BinaryNode:
  def __init__(self, value, left=None, right=None):
    self.data = value
    self.left = left
    self.right = right

class BinarySearchNode:
  def __init__( self ):
    self.root = None

  def insert( self, value ):
    if self.root == None:
      self.root = BinaryNode( value )
    else:
      self.__insert_nodo( self.root, value )
  
  def __insert_nodo( self, nodo, value ):
    if nodo.data == value:
      pass
    elif value < nodo.data:  
      if nodo.left == None:
        nodo.left = BinaryNode( value )
      else:
        self.__insert_nodo( nodo.left, value )
    else:   
      if nodo.right == None:
        nodo.right = BinaryNode( value )
      else:
        self.__insert_nodo( nodo.right, value )

  def transversal( self, formato = "posorden"):
    if formato == "posorden":
      self.recorrido_pos( self.root )
    elif formato == "preorden":
      self.recorrido_pre( self.root )
    else:   # Inorden
      self.recorrido_in( self.root )
    print()

  def recorrido_pos( self, nodo ):
    if nodo != None:
      self.recorrido_pos( nodo.left )
      self.recorrido_pos( nodo.right )
      print(str( nodo.data ))

  def recorrido_pre( self, nodo ):
    if nodo != None:
      print(str( nodo.data ))
      self.recorrido_pre( nodo.left )
      self.recorrido_pre( nodo.right )

  def recorrido_in( self, nodo ):
    if nodo != None:
      self.recorrido_in( nodo.left )
      print(str( nodo.data ))
      self.recorrido_in( nodo.right )

  def search( self, value ):
    if self.root == None:
      print("El árbol está vacío")
      return None
    else:
      return self.__search( self.root, value )

  def __search( self, nodo, value ):
    if nodo == None:
      print("El dato no existe en el árbol")
    elif nodo.data == value:
      print("Encontrado", nodo.data)
      return nodo
    elif value < nodo.data:
      return self.__search( nodo.left, value )
    else:
      return self.__search( nodo.right, value )
  
  def remove(self, value ):
    if self.root == None:
      print("Árbol vacío")
   
    else:
      self.__remove(None, None, self.root, value)

  def __remove(self, padre_hi, padre_hd, actual, value):
    if actual == None:
      print("Caso base")
      return None
    elif actual.data == value:
      print("\nEncontrado", actual.data) 
      
     def remove( self , value ):
    if self.root == None:
      print("No existen valores en el árbol") 
      return None
    else:
      hallado = self.search_remove( self.root , value )
      if hallado.left == None and hallado.rigth == None: #1 "EL NODO ES  HOJA"
        hallado.data = None
      if hallado.left == None or hallado.rigth == None: #2 "TIENE 1 SOLO HIJO"
        if hallado.left != None:
          guardado = int(hallado.left.data)
          hallado.left = None
          hallado.left = BinaryNode(guardado)
        if hallado.rigth != None:
          guardado = int(hallado.rigth.data)
          hallado.rigth.data = None
          hallado.rigth = BinaryNode(guardado) 
          



  def search_remove( self , nodo , value):
    if nodo == None:    
      return None
    elif nodo.data == value:
      return nodo
    elif value < nodo.data:
      return self.search_remove( nodo.left , value )  
    else:
      return self.search_remove( nodo.rigth , value )

# %%
arb1.remove(15)
arb1.transversal("posorden")
